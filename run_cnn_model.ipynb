# %% [markdown]
# Test only for default line L_out='L24'

# %%
import numpy as np
import gym
from stable_baselines3 import PPO
# from stable_baselines3.common import make_vec_env
from openDSSenv34 import openDSSenv34
#import json
#import datetime as dt
import torch as th
from stable_baselines3.common.utils import set_random_seed
#from feedforwardPolicy import *
from stable_baselines3 import A2C
from numba import jit
from state_action_reward import take_action, get_state
# from CustomPolicies import ActorCriticGCAPSPolicy
from typing import Callable
from stable_baselines3.common.torch_layers import (
    BaseFeaturesExtractor,
    CombinedExtractor,
    FlattenExtractor,
    MlpExtractor,
    NatureCNN,
    create_mlp,
)


import pickle
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

from stable_baselines3.common.env_util import make_vec_env
import time
import datetime
    
class CustomNN(BaseFeaturesExtractor):

    """
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 256):
        from torch import nn
        super(CustomNN, self).__init__(observation_space, features_dim)


        n_flatten = 1521# Need to adjust this to fit in the microgrid state space size

        # define cnn layer for feature extraction
        self.cnn_layers = nn.Sequential(
            nn.Conv1d(1, 100, kernel_size=5, stride=3, padding=1),  # 1st 1D-CNN layer
            nn.ReLU(),
            nn.Conv1d(100, 100, kernel_size=5, stride=3, padding=1),  # 2st 1D-CNN layer
            nn.ReLU(),
            nn.Conv1d(100, 100, kernel_size=5, stride=3, padding=1),  # 2st 1D-CNN layer
            nn.ReLU(),
            nn.Flatten(1,-1),
        )
        # calculate the output shape from cnn_layers
        with th.no_grad():
            n_flatten = self.cnn_layers(
                th.as_tensor(np.empty((1,1,n_flatten))).float()
            ).shape[1]

        # add a linear layer to get expected feature dimention
        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())


    def forward(self, observations):
        # get selected observations as state vector
        if len(observations["Unserved Energy"].shape) == 1:
            data_UE = observations["Unserved Energy"][:, None]
        else:
            data_UE = observations["Unserved Energy"]


        ################### Now Trying with the Unserved Energy into Account ################
        statevec = np.concatenate((data_UE,
                                    observations['NodeFeat(BusVoltage)'].flatten(1,2),
                                    observations['EdgeFeat(branchflow)'][:,:],
                                    observations['Adjacency'].flatten(1,2)), axis=1)

        statevec = np.array(statevec)
        statevec = th.from_numpy(statevec)

        # Add additional dimention to match 1d-cnn layer input shape.
        statevec = statevec.unsqueeze(0)
        statevec = statevec.transpose(1,0)

    
        return self.linear(self.cnn_layers(statevec))

def learning_rate_schedule(initial_value: float) -> Callable[[float], float]:

    def func(progress_remaining: float) -> float:

        return (progress_remaining**2) * initial_value
    return func
# env = openDSSenv()

def make_env(rank, seed=0):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environments you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """
    def _init():
        env = openDSSenv34()
        env.seed(seed + rank)
        return env
    set_random_seed(seed)
    return _init

if __name__ == '__main__':
    # env = openDSSenv34()
    num_cpu = 1
    # env = SubprocVecEnv([make_env(i) for i in range(num_cpu)])
    env=make_vec_env(openDSSenv34,n_envs=num_cpu,seed=0)


    # rms_prop_eps = 1e-5
    # policy_kwargs = dict(
    #     features_extractor_class=CustomNN,
    #     features_extractor_kwargs=dict(features_dim=128),
    #     activation_fn=th.nn.Tanh,
    #     net_arch=[dict(pi=[128,128],vf=[128, 128])],
    #     # optimizer_class = th.optim.RMSprop,
    #     # optimizer_kwargs = dict(alpha=0.89, eps=rms_prop_eps, weight_decay=0)
    # )
    # model = A2C('MultiInputPolicy', env,tensorboard_log="logger_L24/", policy_kwargs=policy_kwargs, verbose=1, n_steps=100,
    #         use_rms_prop=False,
    #             gamma=1.00,
    #             learning_rate= 0.000001 #learning_rate_schedule(0.07),
    #             ).learn(total_timesteps=50000, n_eval_episodes=1, log_interval=1, tb_log_name="L24_MLP")

    policy_kwargs = dict(
        features_extractor_class=CustomNN,
        features_extractor_kwargs=dict(features_dim=256),
        activation_fn=th.nn.Tanh,
        net_arch=[128, 128]
        # optimizer_class = th.optim.RMSprop,
        # optimizer_kwargs = dict(alpha=0.89, eps=rms_prop_eps, weight_decay=0)
    )


    model = PPO('MultiInputPolicy', env,tensorboard_log="logger_L24PPO_CNN/", policy_kwargs=policy_kwargs, verbose=1, n_steps=200, batch_size=100,
                gamma=1.00,
                learning_rate=0.000001,#0.00001 from 0.003 to 5e-6♠
                    ent_coef=0.01# 0.05
                    ).learn(total_timesteps=80000, n_eval_episodes=1, log_interval=1, tb_log_name="R1_Microgrid_env_cnn")

    # model = A2C(ActorCriticGCAPSPolicy, env,tensorboard_log="logger/", policy_kwargs=policy_kwargs, verbose=1, n_steps=1).learn(total_timesteps=20000, n_eval_episodes=1)
    # model = A2C('MultiInputPolicy', env,tensorboard_log="logger/", policy_kwargs=policy_kwargs, verbose=1, n_steps=1).learn(total_timesteps=20000, n_eval_episodes=1)
    #model.learn(total_timesteps=2000)


    log_dir = "."
    model.save(log_dir + "r1_MG_bus_mlp_with_entropy_05_multi_env_L24_PPO"+str(datetime.datetime.now().day)+"_"+str(datetime.datetime.now().hour)+"_"+str(datetime.datetime.now().minute))
# Out:
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Using cpu device
# n_flat: 5600
# Logging to logger_L24PPO_CNN/R1_Microgrid_env_cnn_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1         |
# |    ep_rew_mean     | -6.63e-05 |
# | time/              |           |
# |    fps             | 9         |
# |    iterations      | 1         |
# |    time_elapsed    | 21        |
# |    total_timesteps | 200       |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.68e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 2             |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 400           |
# | train/                  |               |
# |    approx_kl            | 1.7583371e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 0.0109        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0616       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -5.57e-05     |
# |    value_loss           | 0.00437       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.64e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 3             |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 600           |
# | train/                  |               |
# |    approx_kl            | 1.6987325e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0301       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0626       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -5.38e-05     |
# |    value_loss           | 0.000502      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.42e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 4             |
# |    time_elapsed         | 92            |
# |    total_timesteps      | 800           |
# | train/                  |               |
# |    approx_kl            | 1.8179417e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0444       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -5.19e-05     |
# |    value_loss           | 1.11e-05      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -6.29e-05   |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 5           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 1000        |
# | train/                  |             |
# |    approx_kl            | 1.66893e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.24       |
# |    explained_variance   | 0.00039     |
# |    learning_rate        | 1e-06       |
# |    loss                 | -0.0625     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -5.3e-05    |
# |    value_loss           | 9.82e-06    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -0.79         |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 6             |
# |    time_elapsed         | 138           |
# |    total_timesteps      | 1200          |
# | train/                  |               |
# |    approx_kl            | 1.1026859e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0174       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0624       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -3.25e-05     |
# |    value_loss           | 2.16e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.73e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 7            |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 1400         |
# | train/                  |              |
# |    approx_kl            | 5.960464e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.062       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -2.54e-05    |
# |    value_loss           | 31.2         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.38e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 8             |
# |    time_elapsed         | 185           |
# |    total_timesteps      | 1600          |
# | train/                  |               |
# |    approx_kl            | 2.1159648e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0143       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0623       |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -6.22e-05     |
# |    value_loss           | 0.000955      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.18e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 9             |
# |    time_elapsed         | 208           |
# |    total_timesteps      | 1800          |
# | train/                  |               |
# |    approx_kl            | 1.4007092e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0422       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0626       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -6.74e-05     |
# |    value_loss           | 7.32e-05      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.54e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 10            |
# |    time_elapsed         | 232           |
# |    total_timesteps      | 2000          |
# | train/                  |               |
# |    approx_kl            | 1.6391278e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 0.024         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -4.64e-05     |
# |    value_loss           | 9.76e-06      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.38e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 11            |
# |    time_elapsed         | 256           |
# |    total_timesteps      | 2200          |
# | train/                  |               |
# |    approx_kl            | 1.4603138e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0101       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -3.96e-05     |
# |    value_loss           | 8.61e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.44e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 12           |
# |    time_elapsed         | 278          |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 2.324581e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0292      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0625      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -4.75e-05    |
# |    value_loss           | 4.81e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.43e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 13            |
# |    time_elapsed         | 303           |
# |    total_timesteps      | 2600          |
# | train/                  |               |
# |    approx_kl            | 1.9669532e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 0.00535       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -4.75e-05     |
# |    value_loss           | 9.22e-08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.42e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 14           |
# |    time_elapsed         | 327          |
# |    total_timesteps      | 2800         |
# | train/                  |              |
# |    approx_kl            | 3.218651e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.00114     |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0625      |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -5.66e-05    |
# |    value_loss           | 5.18e-09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.29e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 15            |
# |    time_elapsed         | 349           |
# |    total_timesteps      | 3000          |
# | train/                  |               |
# |    approx_kl            | 2.7120112e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0421       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -4.8e-05      |
# |    value_loss           | 5.69e-08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.55e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 16            |
# |    time_elapsed         | 373           |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 2.7418135e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0329       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -4.74e-05     |
# |    value_loss           | 1.95e-08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.6e-05     |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 17           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 3400         |
# | train/                  |              |
# |    approx_kl            | 3.039837e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.05        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0625      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -5.6e-05     |
# |    value_loss           | 8.61e-08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.27e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 18            |
# |    time_elapsed         | 417           |
# |    total_timesteps      | 3600          |
# | train/                  |               |
# |    approx_kl            | 1.7583371e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0407       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -3.91e-05     |
# |    value_loss           | 1.15e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.23e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 19            |
# |    time_elapsed         | 440           |
# |    total_timesteps      | 3800          |
# | train/                  |               |
# |    approx_kl            | 1.4901161e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.00429      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -4.09e-05     |
# |    value_loss           | 7.75e-08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.39e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 20            |
# |    time_elapsed         | 463           |
# |    total_timesteps      | 4000          |
# | train/                  |               |
# |    approx_kl            | 3.0994414e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 0.0174        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -4.83e-05     |
# |    value_loss           | 7.49e-08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.82e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 21           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 4200         |
# | train/                  |              |
# |    approx_kl            | 6.884336e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0181      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0626      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -7.45e-05    |
# |    value_loss           | 9.34e-08     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -6.41e-05   |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 22          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 4400        |
# | train/                  |             |
# |    approx_kl            | 6.67572e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.24       |
# |    explained_variance   | -0.0183     |
# |    learning_rate        | 1e-06       |
# |    loss                 | -0.0626     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -9.7e-05    |
# |    value_loss           | 1.27e-07    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -6.52e-05   |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 23          |
# |    time_elapsed         | 534         |
# |    total_timesteps      | 4600        |
# | train/                  |             |
# |    approx_kl            | 7.56979e-08 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.24       |
# |    explained_variance   | 0.0267      |
# |    learning_rate        | 1e-06       |
# |    loss                 | -0.0625     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -7.95e-05   |
# |    value_loss           | 1.02e-07    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.76e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 24           |
# |    time_elapsed         | 558          |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 9.208918e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | 0.00284      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0626      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000101    |
# |    value_loss           | 1.21e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.53e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 25            |
# |    time_elapsed         | 583           |
# |    total_timesteps      | 5000          |
# | train/                  |               |
# |    approx_kl            | 1.2397766e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.11         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0626       |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 1.55e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.6e-05     |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 26           |
# |    time_elapsed         | 609          |
# |    total_timesteps      | 5200         |
# | train/                  |              |
# |    approx_kl            | 8.195639e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0218      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0626      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -8.17e-05    |
# |    value_loss           | 7.94e-08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.68e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 27            |
# |    time_elapsed         | 635           |
# |    total_timesteps      | 5400          |
# | train/                  |               |
# |    approx_kl            | 7.7486035e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0375       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -7.76e-05     |
# |    value_loss           | 5.7e-08       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.57e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 28           |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 5600         |
# | train/                  |              |
# |    approx_kl            | 1.654029e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0762      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0626      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000121    |
# |    value_loss           | 9.31e-08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.04e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 29            |
# |    time_elapsed         | 696           |
# |    total_timesteps      | 5800          |
# | train/                  |               |
# |    approx_kl            | 1.2993812e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 0.00799       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0626       |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -9.52e-05     |
# |    value_loss           | 7.51e-08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.35e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 30           |
# |    time_elapsed         | 726          |
# |    total_timesteps      | 6000         |
# | train/                  |              |
# |    approx_kl            | 6.616116e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | 0            |
# |    learning_rate        | 1e-06        |
# |    loss                 | 35           |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -4.68e-05    |
# |    value_loss           | 35.1         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.56e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 31            |
# |    time_elapsed         | 755           |
# |    total_timesteps      | 6200          |
# | train/                  |               |
# |    approx_kl            | 8.4936616e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0235       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -6.8e-06      |
# |    value_loss           | 0.00168       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.34e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 32            |
# |    time_elapsed         | 785           |
# |    total_timesteps      | 6400          |
# | train/                  |               |
# |    approx_kl            | 1.0728836e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0201       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000101     |
# |    value_loss           | 6.39e-05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.34e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 33           |
# |    time_elapsed         | 815          |
# |    total_timesteps      | 6600         |
# | train/                  |              |
# |    approx_kl            | 2.014637e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.032       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0625      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000122    |
# |    value_loss           | 1.38e-05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.77e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 34            |
# |    time_elapsed         | 846           |
# |    total_timesteps      | 6800          |
# | train/                  |               |
# |    approx_kl            | 1.9669534e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0476       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0627       |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.00014      |
# |    value_loss           | 3.7e-06       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.48e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 35            |
# |    time_elapsed         | 873           |
# |    total_timesteps      | 7000          |
# | train/                  |               |
# |    approx_kl            | 2.3901464e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0238       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0628       |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.00017      |
# |    value_loss           | 3.66e-08      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.38e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 36            |
# |    time_elapsed         | 904           |
# |    total_timesteps      | 7200          |
# | train/                  |               |
# |    approx_kl            | 1.6361474e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.033        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0626       |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000125     |
# |    value_loss           | 1.8e-07       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.39e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 37            |
# |    time_elapsed         | 937           |
# |    total_timesteps      | 7400          |
# | train/                  |               |
# |    approx_kl            | 2.3841858e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0458       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0627       |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000144     |
# |    value_loss           | 2.36e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.25e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 38            |
# |    time_elapsed         | 963           |
# |    total_timesteps      | 7600          |
# | train/                  |               |
# |    approx_kl            | 3.4600498e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0253       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0627       |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000163     |
# |    value_loss           | 3.5e-08       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.35e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 39            |
# |    time_elapsed         | 991           |
# |    total_timesteps      | 7800          |
# | train/                  |               |
# |    approx_kl            | 2.3007394e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.036        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000106     |
# |    value_loss           | 8.95e-09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.68e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 40            |
# |    time_elapsed         | 1016          |
# |    total_timesteps      | 8000          |
# | train/                  |               |
# |    approx_kl            | 1.7344952e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0641       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -8.94e-05     |
# |    value_loss           | 1.48e-08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.73e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 41           |
# |    time_elapsed         | 1041         |
# |    total_timesteps      | 8200         |
# | train/                  |              |
# |    approx_kl            | 3.013015e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.00753     |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0626      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000137    |
# |    value_loss           | 1.54e-08     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.42e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 42           |
# |    time_elapsed         | 1066         |
# |    total_timesteps      | 8400         |
# | train/                  |              |
# |    approx_kl            | 2.232194e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0259      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0627      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000126    |
# |    value_loss           | 2.93e-09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.6e-05      |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 43            |
# |    time_elapsed         | 1091          |
# |    total_timesteps      | 8600          |
# | train/                  |               |
# |    approx_kl            | 3.3736228e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0253       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0625       |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000142     |
# |    value_loss           | 1.1e-08       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.46e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 44            |
# |    time_elapsed         | 1119          |
# |    total_timesteps      | 8800          |
# | train/                  |               |
# |    approx_kl            | 4.2647122e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0296       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0629       |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000216     |
# |    value_loss           | 1.01e-08      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.48e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 45           |
# |    time_elapsed         | 1144         |
# |    total_timesteps      | 9000         |
# | train/                  |              |
# |    approx_kl            | 5.719065e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0283      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0629      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000236    |
# |    value_loss           | 5.56e-09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.34e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 46            |
# |    time_elapsed         | 1170          |
# |    total_timesteps      | 9200          |
# | train/                  |               |
# |    approx_kl            | 4.2676925e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 0.00483       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0628       |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000172     |
# |    value_loss           | 1.67e-09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.51e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 47            |
# |    time_elapsed         | 1193          |
# |    total_timesteps      | 9400          |
# | train/                  |               |
# |    approx_kl            | 5.5104493e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0115       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0628       |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000217     |
# |    value_loss           | 2.08e-09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.4e-05     |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 48           |
# |    time_elapsed         | 1217         |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 6.470084e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0155      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0628      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000259    |
# |    value_loss           | 9.95e-10     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -6.73e-05   |
# | time/                   |             |
# |    fps                  | 7           |
# |    iterations           | 49          |
# |    time_elapsed         | 1241        |
# |    total_timesteps      | 9800        |
# | train/                  |             |
# |    approx_kl            | 6.28531e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.24       |
# |    explained_variance   | -0.0456     |
# |    learning_rate        | 1e-06       |
# |    loss                 | -0.0629     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.000257   |
# |    value_loss           | 1.12e-08    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.22e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 50           |
# |    time_elapsed         | 1266         |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 9.393692e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0242      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.063       |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000285    |
# |    value_loss           | 3.57e-08     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.28e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 51            |
# |    time_elapsed         | 1289          |
# |    total_timesteps      | 10200         |
# | train/                  |               |
# |    approx_kl            | 8.9138746e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0344       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0629       |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.000305     |
# |    value_loss           | 5.7e-07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.4e-05     |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 52           |
# |    time_elapsed         | 1310         |
# |    total_timesteps      | 10400        |
# | train/                  |              |
# |    approx_kl            | 7.745624e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0269      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0629      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000307    |
# |    value_loss           | 5.61e-07     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | -6.57e-05  |
# | time/                   |            |
# |    fps                  | 7          |
# |    iterations           | 53         |
# |    time_elapsed         | 1334       |
# |    total_timesteps      | 10600      |
# | train/                  |            |
# |    approx_kl            | 8.2165e-07 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.24      |
# |    explained_variance   | -0.00449   |
# |    learning_rate        | 1e-06      |
# |    loss                 | -0.0629    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.000265  |
# |    value_loss           | 3.08e-07   |
# ----------------------------------------
# ...
# |    explained_variance   | -0.0445       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0632       |
# |    n_updates            | 650           |
# |    policy_gradient_loss | -0.000419     |
# |    value_loss           | 2.14e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.32e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 67            |
# |    time_elapsed         | 1667          |
# |    total_timesteps      | 13400         |
# | train/                  |               |
# |    approx_kl            | 2.3642183e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.019        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0637       |
# |    n_updates            | 660           |
# |    policy_gradient_loss | -0.000482     |
# |    value_loss           | 3.1e-07       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.29e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 68           |
# |    time_elapsed         | 1690         |
# |    total_timesteps      | 13600        |
# | train/                  |              |
# |    approx_kl            | 3.372431e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0368      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0637      |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.000545    |
# |    value_loss           | 4.77e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.55e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 69            |
# |    time_elapsed         | 1712          |
# |    total_timesteps      | 13800         |
# | train/                  |               |
# |    approx_kl            | 2.4324654e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.00894      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0633       |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -0.000492     |
# |    value_loss           | 2.64e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.29e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 70            |
# |    time_elapsed         | 1735          |
# |    total_timesteps      | 14000         |
# | train/                  |               |
# |    approx_kl            | 2.6488306e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.00641      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0634       |
# |    n_updates            | 690           |
# |    policy_gradient_loss | -0.000456     |
# |    value_loss           | 3.97e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.39e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 71            |
# |    time_elapsed         | 1758          |
# |    total_timesteps      | 14200         |
# | train/                  |               |
# |    approx_kl            | 1.8203259e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.00753      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0631       |
# |    n_updates            | 700           |
# |    policy_gradient_loss | -0.000362     |
# |    value_loss           | 2.88e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.16e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 72            |
# |    time_elapsed         | 1780          |
# |    total_timesteps      | 14400         |
# | train/                  |               |
# |    approx_kl            | 2.5457143e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0247       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0634       |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.000534     |
# |    value_loss           | 4.09e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.59e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 73            |
# |    time_elapsed         | 1803          |
# |    total_timesteps      | 14600         |
# | train/                  |               |
# |    approx_kl            | 2.8479099e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.047        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0635       |
# |    n_updates            | 720           |
# |    policy_gradient_loss | -0.000505     |
# |    value_loss           | 4.28e-07      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.58e-05    |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 74           |
# |    time_elapsed         | 1826         |
# |    total_timesteps      | 14800        |
# | train/                  |              |
# |    approx_kl            | 3.145039e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.0286      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0633      |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00053     |
# |    value_loss           | 4.62e-07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.26e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 75            |
# |    time_elapsed         | 1848          |
# |    total_timesteps      | 15000         |
# | train/                  |               |
# |    approx_kl            | 2.7957558e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0281       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0636       |
# |    n_updates            | 740           |
# |    policy_gradient_loss | -0.000531     |
# |    value_loss           | 5.22e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.34e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 76            |
# |    time_elapsed         | 1871          |
# |    total_timesteps      | 15200         |
# | train/                  |               |
# |    approx_kl            | 3.5229325e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.00343      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0634       |
# |    n_updates            | 750           |
# |    policy_gradient_loss | -0.000551     |
# |    value_loss           | 8.67e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.53e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 77            |
# |    time_elapsed         | 1894          |
# |    total_timesteps      | 15400         |
# | train/                  |               |
# |    approx_kl            | 2.6595594e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.00804      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0632       |
# |    n_updates            | 760           |
# |    policy_gradient_loss | -0.000473     |
# |    value_loss           | 4.87e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.36e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 78            |
# |    time_elapsed         | 1916          |
# |    total_timesteps      | 15600         |
# | train/                  |               |
# |    approx_kl            | 2.5638938e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0498       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0636       |
# |    n_updates            | 770           |
# |    policy_gradient_loss | -0.00056      |
# |    value_loss           | 5.32e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.86e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 79            |
# |    time_elapsed         | 1939          |
# |    total_timesteps      | 15800         |
# | train/                  |               |
# |    approx_kl            | 2.1517276e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | -0.0141       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0633       |
# |    n_updates            | 780           |
# |    policy_gradient_loss | -0.000421     |
# |    value_loss           | 4.29e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.47e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 80            |
# |    time_elapsed         | 1960          |
# |    total_timesteps      | 16000         |
# | train/                  |               |
# |    approx_kl            | 3.2189487e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | -0.0519       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0639       |
# |    n_updates            | 790           |
# |    policy_gradient_loss | -0.000636     |
# |    value_loss           | 7.17e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.34e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 81            |
# |    time_elapsed         | 1983          |
# |    total_timesteps      | 16200         |
# | train/                  |               |
# |    approx_kl            | 2.8231739e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | -0.0177       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0631       |
# |    n_updates            | 800           |
# |    policy_gradient_loss | -0.000446     |
# |    value_loss           | 4.84e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.31e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 82            |
# |    time_elapsed         | 2004          |
# |    total_timesteps      | 16400         |
# | train/                  |               |
# |    approx_kl            | 3.1507016e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | -0.00711      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0633       |
# |    n_updates            | 810           |
# |    policy_gradient_loss | -0.000515     |
# |    value_loss           | 4.28e-07      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.56e-05     |
# | time/                   |               |
# |    fps                  | 8             |
# |    iterations           | 83            |
# |    time_elapsed         | 2027          |
# |    total_timesteps      | 16600         |
# | train/                  |               |
# |    approx_kl            | 3.2323599e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | -0.0164       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0638       |
# |    n_updates            | 820           |
# |    policy_gradient_loss | -0.000536     |
# |    value_loss           | 5.98e-07      |
# -------------------------------------------

# %% [markdown]
# The training is done. Now, test it.

# %%
import openDSSenv34
import importlib
importlib.reload(openDSSenv34)
from openDSSenv34 import openDSSenv34

env = openDSSenv34()
obs, DSSCKTOBJ, G_INIT = env.new_test_func()
start = time.time()
obs = {key: th.as_tensor([_obs]) for (key, _obs) in obs.items()}
obs['loss'] = th.as_tensor([[obs['loss']]])
#obs['TopologicalConstr'] = torch.as_tensor([[obs['TopologicalConstr']]])
obs['VoltageViolation'] = th.as_tensor([[obs['VoltageViolation']]])
obs['FlowViolation'] = th.as_tensor([[obs['FlowViolation']]])


action, values, log_probs = model.policy.forward(obs)
#print(obs['loss'])
DCKTOBJ=take_action(DSSCKTOBJ,action)
OBS=get_state(DSSCKTOBJ,G_INIT)
print("The loss is:",OBS['loss'])
print("The topology violation status is:",OBS['TopologicalConstr'])
print("The voltage violation status is: ",OBS['VoltageViolation'])
print("The branch flow violation status is: ",OBS['FlowViolation'])
print("The amount of unserved energy is:",OBS['Unserved Energy']*1000*25)
#print("The voltage violation status is:",OBS['VoltageViolation'])
print("The convergence status is:",OBS['Convergence'])
print("For Unity Load: The Optimal Configuration is :.{}",action)
end = time.time()
print("Run time [s]: ",end-start)
